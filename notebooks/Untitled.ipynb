# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import missingno as msno

# %% [markdown]
# ### Dataset loading for visualisation

# %%
url="https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
df_country=pd.read_csv(url, sep=',')

# %%
df_country
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 196311      ZWE    Africa     Zimbabwe  2022-06-19     254801.0       48.0
# 196312      ZWE    Africa     Zimbabwe  2022-06-20     254831.0       30.0
# 196313      ZWE    Africa     Zimbabwe  2022-06-21     254919.0       88.0
# 196314      ZWE    Africa     Zimbabwe  2022-06-22     255049.0      130.0
# 196315      ZWE    Africa     Zimbabwe  2022-06-23     255136.0       87.0
#
# ...

# %%
# df_country.to_csv('covid_full_data.csv')
len(df_country['location'].unique())
# Out:
# 244

# %%
df_country['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_germany = df_country[df_country['location']=='Germany']

# %%
df_germany
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 66199      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 66200      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 66201      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 66202      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 66203      DEU    Europe  Germany  2020-01-31          5.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 67073      DEU    Europe  Germany  2022-06-19   27211896.0     6941.0
# 67074      DEU    Europe  Germany  2022-06-20   27334993.0   123097.0
# 67075      DEU    Europe  Germany  2022-06-21   27454225.0   119232.0
# 67076      DEU    Europe  Germany  2022-06-22   27573585.0   119360.0
# 67077      DEU    Europe  Germany  2022-06-23   27681775.0   108190.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_germany = df_germany.reset_index(drop=True)

# %%
df_germany
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 0        DEU    Europe  Germany  2020-01-27          1.0        1.0
# 1        DEU    Europe  Germany  2020-01-28          4.0        3.0
# 2        DEU    Europe  Germany  2020-01-29          4.0        0.0
# 3        DEU    Europe  Germany  2020-01-30          4.0        0.0
# 4        DEU    Europe  Germany  2020-01-31          5.0        1.0
# ..       ...       ...      ...         ...          ...        ...
# 874      DEU    Europe  Germany  2022-06-19   27211896.0     6941.0
# 875      DEU    Europe  Germany  2022-06-20   27334993.0   123097.0
# 876      DEU    Europe  Germany  2022-06-21   27454225.0   119232.0
# 877      DEU    Europe  Germany  2022-06-22   27573585.0   119360.0
# 878      DEU    Europe  Germany  2022-06-23   27681775.0   108190.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
fig=px.line(df_germany, x='date', y='total_cases', title="COVID cases")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ANSHUG~1\AppData\Local\Temp/ipykernel_1932/3591164413.py in <module>
# ----> 1 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %%
(df_germany['total_cases']/df_germany['population'])*100
# Out:
# 0       0.000001
# 1       0.000005
# 2       0.000005
# 3       0.000005
# 4       0.000006
#          ...
# 874    32.433544
# 875    32.580262
# 876    32.722373
# 877    32.864637
# 878    32.993587
# Length: 879, dtype: float64

# %%
df_germany = df_country[df_country['location']=='Germany']
df_US = df_country[df_country['location']=='United States']
b_all= df_germany or df_US
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ANSHUG~1\AppData\Local\Temp/ipykernel_1932/141261106.py in <module>
#       1 df_germany = df_country[df_country['location']=='Germany']
#       2 df_US = df_country[df_country['location']=='United States']
# ----> 3 b_all= df_germany or df_US
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
